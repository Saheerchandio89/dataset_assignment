# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('customer_booking1.csv')
df
# Out:
#      num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                 2      Internet  RoundTrip            262              19
# 1                 1      Internet  RoundTrip            112              20
# 2                 2      Internet  RoundTrip            243              22
# 3                 1      Internet  RoundTrip             96              31
# 4                 2      Internet  RoundTrip             68              22
# ..              ...           ...        ...            ...             ...
# 494               1      Internet  RoundTrip             41              41
# 495               2      Internet  RoundTrip             40              63
# 496               1      Internet  RoundTrip              5              28
# 497               2        Mobile  RoundTrip             79              37
# 498               1        Mobile  RoundTrip             94              64
#
# ...

# %%
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
df.tail()
# Out:
#      num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 494               1      Internet  RoundTrip             41              41
# 495               2      Internet  RoundTrip             40              63
# 496               1      Internet  RoundTrip              5              28
# 497               2        Mobile  RoundTrip             79              37
# 498               1        Mobile  RoundTrip             94              64
#
#      flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 494           15        Mon  AKLKUL       Malaysia                    1
# 495            9        Mon  AKLKUL    New Zealand                    1
# 496            9        Mon  AKLKUL    New Zealand                    1
# 497           11        Sun  AKLKUL       Malaysia                    1
# 498            9        Sun  AKLKUL       Malaysia                    1
#
#      wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
df.head(2)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             5.52
# 1                     0                      0             5.52
#
#    booking_complete
# 0                 0
# 1                 0

# %%
df.tail(3)
# Out:
#      num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 496               1      Internet  RoundTrip              5              28
# 497               2        Mobile  RoundTrip             79              37
# 498               1        Mobile  RoundTrip             94              64
#
#      flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 496            9        Mon  AKLKUL    New Zealand                    1
# 497           11        Sun  AKLKUL       Malaysia                    1
# 498            9        Sun  AKLKUL       Malaysia                    1
#
#      wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 496                     0                      1             8.83
# 497                     0                      1             8.83
# 498                     1                      0             8.83
#
#      booking_complete
# 496                 1
# 497                 0
# 498                 0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                 2      Internet  RoundTrip            262              19
# 1                 1      Internet  RoundTrip            112              20
# 2                 2      Internet  RoundTrip            243              22
# 3                 1      Internet  RoundTrip             96              31
# 4                 2      Internet  RoundTrip             68              22
# ..              ...           ...        ...            ...             ...
# 494               1      Internet  RoundTrip             41              41
# 495               2      Internet  RoundTrip             40              63
# 496               1      Internet  RoundTrip              5              28
# 497               2        Mobile  RoundTrip             79              37
# 498               1        Mobile  RoundTrip             94              64
#
# ...

# %%
df.columns
# Out:
# Index(['num_passengers', 'sales_channel', 'trip_type', 'purchase_lead',
#        'length_of_stay', 'flight_hour', 'flight_day', 'route',
#        'booking_origin', 'wants_extra_baggage', 'wants_preferred_seat',
#        'wants_in_flight_meals', 'flight_duration', 'booking_complete'],
#       dtype='object')

# %%
plt.plot(df[['length_of_stay','flight_hour']],color='black', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='red', markersize=12)
plt.ylabel('length_of_stay')
plt.xlabel('flight_hour')
plt.title('Length of stay vs duration of flight')
plt.show()

# %%
plt.scatter(df['length_of_stay'],df['flight_hour'], color = 'lightcoral')
plt.plot(df['length_of_stay'],df['flight_hour'], color = 'firebrick')
plt.title('length_of_stay vs flight_hour ')
plt.xlabel('Budget_asset')
plt.ylabel('Total loss Cost (Millions of Dollars)')
plt.box(True)
plt.show()

# %%
arr=np.array([0,9,7])
print(arr)
# Out:
# [0 9 7]

# %%
print(arr*2)
# Out:
# [ 0 18 14]

# %%
arr=np.zeros((3,2))
print(arr)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
arr=np.ones((2,2))
print(arr)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
arr=np.eye(3)
print(arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
ar=np.array([[2,4,6],[5,8,9]])
arr=np.array([[1,3,7],[4,9,4]])
print(ar-arr)
# Out:
# [[ 1  1 -1]
#  [ 1 -1  5]]
